# %%
import os
import spotipy
import spotipy.util as util
from spotipy.oauth2 import SpotifyOAuth
client_id = SPOTIPY_CLIENT_ID ='bb7c475418484e7784d9cd25b5f9f52c'
client_secret = SPOTIPY_CLIENT_SECRET='b0da0baeeab1499884912aea11f4ca58'
redirect_uri =SPOTIPY_REDIRECT_URI='https://localhost:8080/callback/'


os.environ["SPOTIPY_CLIENT_ID"] = "bb7c475418484e7784d9cd25b5f9f52c"
os.environ["SPOTIPY_CLIENT_SECRET"] = "b0da0baeeab1499884912aea11f4ca58"
os.environ["SPOTIPY_REDIRECT_URI"] = "https://localhost:8080/callback/"

scope = "playlist-modify-public playlist-modify-private user-modify-playback-state user-top-read"
scope +=            " user-modify-playback-state user-read-playback-state user-library-read user-library-modify"
username = 'tonyryanworldwide'

        
token = util.prompt_for_user_token(username, scope, client_id, client_secret, redirect_uri)        
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope,username=username))

# %%
playlists = sp.user_playlists(username,offset=0)['items']

# sp.recommendations()
for playlist in playlists:
    tracklist = []
    id = playlist['id']
    tracks = sp.user_playlist_tracks(user =username, playlist_id = id )['items']
    tracklist = []
    for track in tracks:
    
        trackid = track['track']['id']
        tracklist.append(trackid)
    recos = sp.recommendations(seed_tracks =tracklist, limit =100)
    print(recos['tracks'])
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/recommendations returned 400 due to invalid request
# [{'album': {'album_type': 'ALBUM', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/62BcWP4fzR8axESibNQEhs'}, 'href': 'https://api.spotify.com/v1/artists/62BcWP4fzR8axESibNQEhs', 'id': '62BcWP4fzR8axESibNQEhs', 'name': 'Butthole Surfers', 'type': 'artist', 'uri': 'spotify:artist:62BcWP4fzR8axESibNQEhs'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/1nrZ789CcB2NWW3xn8MBfe'}, 'href': 'https://api.spotify.com/v1/albums/1nrZ789CcB2NWW3xn8MBfe', 'id': '1nrZ789CcB2NWW3xn8MBfe', 'images': [{'height': 640, 'url': 'https://i.scdn.co/image/ab67616d0000b2734288c2f0d8ce4a998fb80f98', 'width': 640}, {'height': 300, 'url': 'https://i.scdn.co/image/ab67616d00001e024288c2f0d8ce4a998fb80f98', 'width': 300}, {'height': 64, 'url': 'https://i.scdn.co/image/ab67616d000048514288c2f0d8ce4a998fb80f98', 'width': 64}], 'name': 'Weird Revolution', 'release_date': '2001-08-28', 'release_date_precision': 'day', 'total_tracks': 0, 'type': 'album', 'uri': 'spotify:album:1nrZ789CcB2NWW3xn8MBfe'}, 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/62BcWP4fzR8axESibNQEhs'}, 'href': 'https://api.spotify.com/v1/artists/62BcWP4fzR8axESibNQEhs', 'id': '62BcWP4fzR8axESibNQEhs', 'name': 'Butthole Surfers', 'type': 'artist', 'uri': 'spotify:artist:62BcWP4fzR8axESibNQEhs'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'disc_number': 1, 'duration_ms': 222706, 'explicit': False, 'external_ids': {'isrc': 'USHR10110054'}, 'external_urls': {'spotify': 'https://open.spotify.com/track/4KJKj7GZLzxq1bXRu0XP6l'}, 'href': 'https://api.spotify.com/v1/tracks/4KJKj7GZLzxq1bXRu0XP6l', 'id': '4KJKj7GZLzxq1bXRu0XP6l', 'is_local': False, 'name': 'Dracula From Houston', 'popularity': 44, 'preview_url': None, 'track_number': 3, 'type': 'track', 'uri': 'spotify:track:4KJKj7GZLzxq1bXRu0XP6l'}, {'album': {'album_type': 'ALBUM', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5UqTO8smerMvxHYA5xsXb6'}, 'href': 'https://api.spotify.com/v1/artists/5UqTO8smerMvxHYA5xsXb6', 'id': '5UqTO8smerMvxHYA5xsXb6', 'name': 'Sonic Youth', 'type': 'artist', 'uri': 'spotify:artist:5UqTO8smerMvxHYA5xsXb6'}], 'available_markets': ['AD', 'AE', 'AL', 'AR', 'AT', 'AU', 'BA', 'BE', 'BG', 'BH', 'BO', 'BR', 'BY', 'CA', 'CH', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DE', 'DK', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FR', 'GB', 'GR', 'GT', 'HK', 'HN', 'HR', 'HU', 'ID', 'IE', 'IL', 'IN', 'IS', 'IT', 'JO', 'JP', 'KW', 'KZ', 'LB', 'LI', 'LT', 'LU', 'LV', 'MA', 'MC', 'MD', 'ME', 'MK', 'MT', 'MX', 'MY', 'NI', 'NL', 'NO', 'NZ', 'OM', 'PA', 'PE', 'PH', 'PL', 'PS', 'PT', 'PY', 'QA', 'RO', 'RS', 'RU', 'SA', 'SE', 'SG', 'SI', 'SK', 'SV', 'TH', 'TN', 'TR', 'TW', 'UA', 'US', 'UY', 'VN', 'XK', 'ZA'], 'external_urls': {'spotify': 'https://open.spotify.com/album/5iYYQwB0oH9FVyVlaOXZdr'}, 'href': 'https://api.spotify.com/v1/albums/5iYYQwB0oH9FVyVlaOXZdr', 'id': '5i ...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     171
# --> 172             response.raise_for_status()
#     173             results = response.json()
#
# ~\Anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.spotify.com/v1/recommendations?limit=100&seed_tracks=5QemHQxj7PRkrw8lJl2W7C%2C09ZeNJ09kGQDdlvdPJ2Vfd%2C3hR48Bj9Wgl6xunDG4nsRZ%2C1RUTIdTnFs8lHSc0Zr4UJB%2C0rFpcfF0YfvFUYsl99Bw9d%2C0RXspLL7GwiGm9KIDdT0ma%2C38RSpldD3Vlc7Uud9gAxFG%2C3Ygy1L8ABabUA7MwoOLiPM%2C0ujsBQIHVikzdQOekiu5gS%2C3HG3QFERdP3Q1b6VGahwWs%2C03MWa1FMygR3RrQoQytsjS%2C1yp5HJr4YAVZeWqkBfAGH5%2C1iLwMxZsicRFj3Ku2ZKXNd%2C6xeTNdPnP5imNgDzFMfVfD%2C4FgcgJpZaKJRog2EISGWjN%2C5wfllwdjglyQislkskYLBv%2C7dZAPeA3Of5j5Vaef0DQ6M%2C6MtKObWYda2qnNIpJI21uD%2C78T9DulqSBWqkaxczcGBfk%2C7qHAjAL7CpadaZLamuBZRm%2C32Wp1yCGyIas6Ro9xM7lkJ%2C0x9HPHvbIAySJlZU00cmNp%2C7mE0Heyd1SRvhRJPrXI7FI%2C1muLq1kBLWIT3pmNC2xl0g%2C32a0GKG71WxRfIeJI2zre4%2C0WccCTWCY2Jtlh1ddAUZxT
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-21-10ba6a8895a2> in <module>
#      11         trackid = track['track']['id']
#      12         tracklist.append(trackid)
# ---> 13     recos = sp.recommendations(seed_tracks =tracklist, limit =100)
#      14     print(recos['tracks'])
#      15
#
# ~\Anaconda3\lib\site-packages\spotipy\client.py in recommendations(self, seed_artists, seed_genres, seed_tracks, limit, country, **kwargs)
#    1217                 if param in kwargs:
#    1218                     params[param] = kwargs[param]
# -> 1219         return self._get("recommendations", **params)
#    1220
#    1221     def recommendation_genre_seeds(self):
#
# ~\Anaconda3\lib\site-packages\spotipy\client.py in _get(self, url, args, payload, **kwargs)
#     205             kwargs.update(args)
#     206
# --> 207         return self._internal_call("GET", url, payload, kwargs)
#     208
#     209     def _post(self, url, args=None, payload=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\spotipy\client.py in _internal_call(self, method, url, payload, params)
#     185                 -1,
#     186                 "%s:\n %s" % (response.url, msg),
# --> 187                 headers=response.headers,
#     188             )
#     189         except requests.exceptions.RetryError:
#
# SpotifyException: http status: 400, code:-1 - https://api.spotify.com/v1/recommendations?limit=100&seed_tracks=5QemHQxj7PRkrw8lJl2W7C%2C09ZeNJ09kGQDdlvdPJ2Vfd%2C3hR48Bj9Wgl6xunDG4nsRZ%2C1RUTIdTnFs8lHSc0Zr4UJB%2C0rFpcfF0YfvFUYsl99Bw9d%2C0RXspLL7GwiGm9KIDdT0ma%2C38RSpldD3Vlc7Uud9gAxFG%2C3Ygy1L8ABabUA7MwoOLiPM%2C0ujsBQIHVikzdQOekiu5gS%2C3HG3QFERdP3Q1b6VGahwWs%2C03MWa1FMygR3RrQoQytsjS%2C1yp5HJr4YAVZeWqkBfAGH5%2C1iLwMxZsicRFj3Ku2ZKXNd%2C6xeTNdPnP5imNgDzFMfVfD%2C4FgcgJpZaKJRog2EISGWjN%2C5wfllwdjglyQislkskYLBv%2C7dZAPeA3Of5j5Vaef0DQ6M%2C6MtKObWYda2qnNIpJI21uD%2C78T9DulqSBWqkaxczcGBfk%2C7qHAjAL7CpadaZLamuBZRm%2C32Wp1yCGyIas6Ro9xM7lkJ%2C0x9HPHvbIAySJlZU00cmNp%2C7mE0Heyd1SRvhRJPrXI7FI%2C1muLq1kBLWIT3pmNC2xl0g%2C32a0GKG71WxRfIeJI2zre4%2C0WccCTWCY2Jtlh1ddAUZxT:
#  invalid request

# %%
import pandas as pd
from pandas import DataFrame
total = sp.current_user_saved_tracks()['total']
offset = 50
savedtracks = sp.current_user_saved_tracks(limit = 50)['items']
while offset < total:
    
    savedtracks2 =sp.current_user_saved_tracks(limit = 50,offset=offset)['items']
    for track in savedtracks2:
        savedtracks.append(track)
    offset += 50

    
trackinfo ={}   
for trackex in savedtracks:
    id = trackex['track']['id']
    name = trackex['track']['name']
    artistid = trackex['track']['artists'][0]['id']
    seconds = trackex['track']['duration_ms']/1000
    trackinfo[trackex['track']['id']] = {"artist" : artistid,"name":name,"seconds":seconds}
    
trackdf = pd.DataFrame.from_dict(trackinfo,orient = "index").reset_index()
artists = trackdf.artist.unique()
trackdf.columns = ['trackid','artistid','trackname','tracklength_sec']

artistinfo = []
i = 0
while i < len(artists) - 50:
    x=sp.artists(artists[i:i+50])['artists']
    artistinfo.append(x)
    i+=50
artistfinal ={}
for i in artistinfo:
    for j in i:   
        id = j['id']
        name = j['name']
        if len(j['genres']) > 0:
            genre = j['genres']#[0]
        else:
            genre = ''
        artistfinal[id] = {"name":name,"genre": genre}          
artistdf = pd.DataFrame.from_dict(artistfinal,orient = "index").reset_index()
artistdf = artistdf.reset_index()[['index','name','genre']]
artistdf.columns = ['artistid','artistname','genre']
artistdf =artistdf[artistdf['genre']!=''].reset_index()[['artistid','artistname','genre']]

# %%
column_names = ["artistid", "artistname", "genre"]

finalartist = pd.DataFrame(columns = column_names)

for i in range(0, len(artistdf)):
    df = artistdf[i:i+1][['artistid','artistname']]
#     print(i)
#     print(df)
    genres = artistdf[i:i+1]['genre'][i]
    gf= DataFrame(genres,columns=['genre'])
    product = (
    df.assign(key=1)
    .merge(gf.assign(key=1), on="key")
    .drop("key", axis=1)
    )
    finalartist = finalartist.append(product)

# %%
finaltrackinfo = trackdf.merge(finalartist, left_on = 'artistid', right_on = 'artistid', how = 'inner' )
finaltrackinfo['cum_sec'] = finaltrackinfo.groupby('genre')['tracklength_sec'].apply(lambda x: x.cumsum())

# %%
genres = finaltrackinfo.groupby('genre').count().reset_index()[['genre','artistid']]
genres.columns=['genre','count']
genres = genres[(genres['count'] >= 25) & (genres['genre']!= '')].sort_values(by ='count', ascending = False)
genrelist = genres['genre'].tolist()
finaltrackinfo = finaltrackinfo[finaltrackinfo['genre'].isin(genres['genre'])]

# %%
def genrefilter(df,gen,sec_lim = 14400):
    dfin = df['trackid'][(df['genre'] == gen) & (df['cum_sec'] <= sec_lim)]
    return dfin.tolist()[0:100]

# %%
for gen in genrelist:
    id = sp.user_playlist_create(user=username,name =gen)['id']
    tracks = genrefilter(finaltrackinfo,gen)
    sp.user_playlist_add_tracks(user = username, playlist_id =id,tracks = tracks,position = 0)

# %% [markdown]
# ## For Debugging Delete CreatedPlaylists

# %%
# playlists =sp.current_user_playlists(offset=100)['items']
playlists = sp.user_playlists(username,offset=0)['items']
for playlist in playlists:
    name= playlist['name']

    
    id = playlist['uri'][-22:]
    
    if name in genrelist:
        print('deleting{0} id {1}'.format(name,id))
        sp.user_playlist_unfollow(user=username, playlist_id = id)
# Out:
# uk americana
# modern folk rock
# sexy time
# sexy time
# August '20
# lex fridman
# YouTube
# JustDance
# High Energy
# July '20
# The Happiest Days of Our Lives
# June '20
# New recos
# Gone
# Yellow Ledbetter
# Generator
# Theta Wave 5Hz
# Steven Halpern – Pain Relief at the Speed of Sound
# Alive Trio
# Family Mix
# Deep Theta 2.0
# May '20
# Don't Stop Believin' - Live Version
# Dancing In the Dark
# April '20
# chill work
# What A Man Gotta Do
# Toad
# March '20
# Power Trip (feat. Miguel)
# Why
# Your Top Songs 2019
# February '20
# Hey Ma
# bruno
# Super Simple Songs – Halloween Songs for Kids
# January '20
# On Repeat
# Repeat Rewind
# December '19
# Bone
# Meditate instrumental
# meditate real songs
# primitive
# Jump Around
# Emma2
# Best Kings
# Aa Put the Lime in the Coconut
# Chill AF OG
# Bad Boy

# %%
# Out:
# Binaural Beats  Beta Frequency
# Binaural Beats 12.5Hz Alpha Frequency
# Summer Song
# Fly By Night
# Under My Thumb
# Liked from Radio
# Binaural Beats 3.5Hz Delta Frequency
